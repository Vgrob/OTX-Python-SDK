# %% [markdown]
# # Using the OTX-Python-SDK

# %% [markdown]
# ## API Key Configuration

# %%
from OTXv2 import OTXv2, IndicatorTypes

# %%
from pandas.io.json import json_normalize

# %%
from datetime import datetime, timedelta

# %%
otx = OTXv2("458044df4b3238308723bc3df5b8bdea1504e5d0e19ac9e2c4f505fd6ffec067")

# %%
hello

# %% [markdown]
# Replace YOUR_KEY with your OTX API key. You can find it on your settings page https://otx.alienvault.com/settings.

# %% [markdown]
# ## Subscriptions

# %% [markdown]
# The getall() method accesses your subscriptions.  It downloads all the OTX pulses and their assocciated indicators of compromise (IOCs) from your account. This includes:
# - All pulses you subscribe to directly
# - All pulses by users you subscribe to
# - OTX pulses you created (including private pulses)
# If this is the first time you are using your account, the download includes all pulses created by AlienVault. All users are subscribed to the AlienVault user by default.

# %%
pulses = otx.getall()

# %%
len(pulses)
# Out:
# 2049

# %% [markdown]
# Let's list a few pulses:

# %%
pulses
# Out:
# {'results': [{'industries': [],
#    'TLP': 'green',
#    'description': 'TV5Monde was taken off air in April 2015. A group calling itself the Cyber Caliphate, linked to so-called Islamic State, first claimed responsibility.\n\nBut an investigation now suggests the attack was in fact carried out by a group of Russian hackers.\n\nThe attack used highly targeted malicious software to destroy the TV network&#39;s systems.',
#    'created': '2015-04-10T18:15:11.492000',
#    'tags': [],
#    'malware_families': [],
#    'modified': '2019-01-25T15:20:10.359000',
#    'author_name': 'AlienVault',
#    'public': 1,
#    'is_subscribing': None,
#    'references': ['https://www.bluecoat.com/security-blog/2015-04-09/visual-basic-script-malware-reportedly-used-tv5-monde-intrusion',
#     'https://www.bbc.co.uk/news/technology-37590375'],
#    'targeted_countries': [],
#    'indicators': [{'indicator': 'aziza12.no-ip.biz',
#      'description': '',
#      'created': '2017-08-24T10:51:55',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3002},
#     {'indicator': 'islamstate.no-ip.biz',
#      'description': '',
#      'created': '2017-08-24T10:51:55',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3003},
#     {'indicator': 'a5ce6dcb062ceb91a6fce73e99b3514d',
#      'description': '',
#      'created': '2017-08-24T10:51:55',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 3005},
#     {'indicator': 'de8e6e14b7e548eda7d4ff33bb3705ad',
#      'description': '',
#      'created': '2017-08-24T10:51:55',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 3006},
#     {'indicator': '2962c44ce678d6ca1246f5ead67d115a',
#      'description': '',
#      'created': '2017-08-24T10:51:55',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 3007}],
#    'attack_ids': [],
#    'author': {'username': 'AlienVault',
#     'is_subscribed': True,
#     'avatar_url': 'https://otx20-web-media.s3.amazonaws.com/media/avatars/user_2/resized/80/avatar_dacfad0ca8.png',
#     'is_following': False,
#     'id': '2'},
#    'revision': 11,
#    'adversary': 'Sofacy',
#    'id': '5528132f13432a2102724d34',
#    'name': 'Potential TV5 Monde intrusion indicators'},
#   {'industries': [],
#    'TLP': 'green',
#    'description': 'FireEye Labs recently detected a limited APT campaign exploiting zero-day vulnerabilities in Adobe Flash and a brand-new one in Microsoft Windows. Using the Dynamic Threat Intelligence Cloud (DTI), FireEye researchers detected a pattern of attacks beginning on April 13th, 2015. Adobe independently patched the vulnerability (CVE-2015-3043) in APSB15-06. Through correlation of technical indicators and command and control infrastructure, FireEye assess that APT28 is probably responsible for this activity.',
#    'created': '2015-04-20T02:56:30.505000',
#    'tags': ['flash',
#     'apt28',
#     'windows',
#     'apt',
#     'shellcode',
#     'zeroday',
#     'sofacy'],
#    'malware_families': [],
#    'modified': '2017-08-24T10:45:07.905000',
#    'author_name': 'AlienVault',
#    'public': 1,
#    'is_subscribing': None,
#    'references': [''],
#    'targeted_countries': [],
#    'indicators': [{'indicator': 'ssl-icloud.com',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4278},
#     {'indicator': 'CVE-2015-3043',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'CVE',
#      'id': 4280},
#     {'indicator': 'CVE-2015-1701',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'CVE',
#      'id': 4281},
#     {'indicator': 'CVE-2014-0515',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'CVE',
#      'id': 4282},
#     {'indicator': 'updatecenter.name',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4283},
#     {'indicator': 'securitypractic.com',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4284},
#     {'indicator': 'pass-google.com',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4285},
#     {'indicator': 'drivers-update.info',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4286},
#     {'indicator': 'nato-press.com',
#      'description': '',
#      'created': '2017-08-24T10:45:08',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4287}],
#    'attack_ids': [],
#    'author': {'username': 'AlienVault',
#     'is_subscribed': True,
#     'avatar_url': 'https://otx20-web-media.s3.amazonaws.com/media/avatars/user_2/resized/80/avatar_dacfad0ca8.png',
#     'is_following': False,
#     'id': '2'},
#    'revision': 3,
#    'adversary': 'Sofacy',
#    'id': '55346adeb45ff536ca3ffd2c',
#    'name': 'Operation RussianDoll'},
#   {'industries': [],
#    'TLP': 'green',
#    'description': 'Operation Buhtrap - The trap for Russian accountants as outlined by welivesecurity.com',
#    'created': '2015-04-20T22:54:45.662000',
#    'tags': ['windows', 'microsoft word', 'backdoor', 'kaspersky', 'carberp'],
#    'malware_families': [],
#    'modified': '2015-04-20T22:54:45.662000',
#    'author_name': 'tomdaq',
#    'public': 1,
#    'is_subscribing': None,
#    'references': [''],
#    'targeted_countries': [],
#    'indicators': [{'indicator': 'priovtb.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4467},
#     {'indicator': 'getdownloadsfile.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4468},
#     {'indicator': 'taatta.net',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4469},
#     {'indicator': 'zubsb.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4470},
#     {'indicator': 'b-kontur.org',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4471},
#     {'indicator': 'sendspace.biz',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4472},
#     {'indicator': 'minbank.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4473},
#     {'indicator': 'kontur-expres.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4474},
#     {'indicator': 'mercurynews.biz',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4475},
#     {'indicator': 'buhgalter-info.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4476},
#     {'indicator': 'agent.one',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4477},
#     {'indicator': 'savefrom.biz',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4478},
#     {'indicator': 'mcb.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4479},
#     {'indicator': 'mdmbank.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4480},
#     {'indicator': 'balans2.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4481},
#     {'indicator': 'pikabu-story.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4482},
#     {'indicator': 'source-forge.info',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4483},
#     {'indicator': 'chelindbank.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4484},
#     {'indicator': 'buhonline.info',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'domain',
#      'id': 4485},
#     {'indicator': 'chelindbank.ru/online/',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 4486},
#     {'indicator': 'playback.savefrom.biz/video/video_1',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3480},
#     {'indicator': 'library.source-forge.info/cab/cabinstal.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3478},
#     {'indicator': 'download.sendspace.biz/file/l.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3486},
#     {'indicator': 'library.source-forge.info/cab/cabinstal3.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3481},
#     {'indicator': 'new.pikabu-story.com/file/file1.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3483},
#     {'indicator': 'playback.savefrom.biz/video/video1.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3479},
#     {'indicator': 'ESET.COM',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 4487},
#     {'indicator': 'new.pikabu-story.com/file/mega.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3482},
#     {'indicator': 'download.sendspace.biz/file/install.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3484},
#     {'indicator': 'getdownloadsfile.com/file/new1.cab',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 3485},
#     {'indicator': 'topic.buhgalter-info.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3487},
#     {'indicator': 'spy.agent.one',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4488},
#     {'indicator': 'isfront.priovtb.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4489},
#     {'indicator': 'download.sendspace.biz',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4490},
#     {'indicator': 'playback.savefrom.biz',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4491},
#     {'indicator': 'balans2w.balans2.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3489},
#     {'indicator': 'forum.buhonline.info',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3490},
#     {'indicator': 'sib.taatta.net',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4492},
#     {'indicator': 'rss.mercurynews.biz',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3488},
#     {'indicator': 'clbank.minbank.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4493},
#     {'indicator': 'new.pikabu-story.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4494},
#     {'indicator': 'beta.mcb.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4495},
#     {'indicator': 'e-plat.mdmbank.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4496},
#     {'indicator': 'sberweb.zubsb.ru',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4497},
#     {'indicator': 'store.kontur-expres.com',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3491},
#     {'indicator': 'help.b-kontur.org',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 3492},
#     {'indicator': 'library.source-forge.info',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 4498},
#     {'indicator': 'efad94fc87b2b3a652f1a98901204ea8fbeef474',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 4499},
#     {'indicator': '9d081716e83c3075b2c80bb8806a257eed35929c',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3471},
#     {'indicator': '3a643be0cea73084c6e4e6fe5dd3626e7f54e9ce',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3473},
#     {'indicator': 'cac0b41ef7eedcd3a8a5f83f7424c426ca05925c',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3472},
#     {'indicator': '81b15a774c2fe146aeebaf9c10a5b907e38cdd26',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3474},
#     {'indicator': '3e1a6e52a1756017dd8f03ff85ec353273b20c66',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 4500},
#     {'indicator': 'b29e9611f081197f273c475c5d185d774b2ca3d2',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3475},
#     {'indicator': '64b79c92388244a8145bb786ba5f6b7d168fe620',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3476},
#     {'indicator': 'cf5a43d14c6ad0c7fdbcbe632ab7c789e39443ee',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 4501},
#     {'indicator': 'ba8168c0b69d345098ebc1c3b7c90ca28097e4ff',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 3477},
#     {'indicator': 'e9af1f9af597a9330c52a7686bf70b0094ad7616',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 4502},
#     {'indicator': '91.218.231.79',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'IPv4',
#      'id': 3493},
#     {'indicator': 'CVE-2012-0158',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'CVE',
#      'id': 813},
#     {'indicator': 'CVE-2013-3660',
#      'description': '',
#      'created': '2015-04-20T22:54:46',
#      'title': '',
#      'content': '',
#      'type': 'CVE',
#      'id': 3494}],
#    'attack_ids': [],
#    'author': {'username': 'tomdaq',
#     'is_subscribed': False,
#     'avatar_url': 'https://otx.alienvault.com/assets/images/default-avatar.png',
#     'is_following': False,
#     'id': '49'},
#    'revision': 1,
#    'adversary': None,
#    'id': '553583b5b45ff501cdc579aa',
#    'name': 'Operation Buhtrap'},
#   {'industries': [],
#    'TLP': 'green',
#    'description': '“Operation Armageddon,” active since at least mid-2013, exposes a cyber espionage campaign devised to provide a military advantage to Russian leadership by targeting Ukrainian government, law enforcement, and military officials in order to steal information that can provide insight into near term Ukrainian intentions and plans. The Security Service of Ukraine (SBU) is continuously investigating this active threat, and has issued statements attributing the attacks to specific branches of the Russian Federal Security Service (FSB). Technical and temporal analysis of the campaign supports these statements and indicates a direct correlation between the cyber attacks and the ongoing war, highlighting an alarming blend between cyber espionage, physical warfare, and the driving political forces behind them.',
#    'created': '2015-04-29T16:11:08.251000',
#    'tags': ['Lookingglass', 'russia', 'ukraine', 'spearphishing'],
#    'malware_families': [],
#    'modified': '2017-03-12T01:33:45.089000',
#    'author_name': 'AlienVault',
#    'public': 1,
#    'is_subscribing': None,
#    'references': [''],
#    'targeted_countries': [],
#    'indicators': [{'indicator': 'downloads.file-attachments.ru/loads/setup_updates',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5940},
#     {'indicator': 'xiaomi-mi.com.ua/images/logo/chrome-xvnc-v5517.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5941},
#     {'indicator': 'muravej.ua/dumper/backup/chrome-xvnc-v5517.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5942},
#     {'indicator': 'xiaomi-mi.com.ua/images/logo/chromeupdates.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5943},
#     {'indicator': 'kif.ru/inc/catalog/FlashPlayerUpdates.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5944},
#     {'indicator': 'muravej.ua/dumper/backup/chromeupdates.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5945},
#     {'indicator': 'cityhotel.kiev.ua/media/editors/codemirror/Attachments_kps@ps',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5946},
#     {'indicator': 'rms.admin-ru.ru/updater.php',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5947},
#     {'indicator': 'http://xakfor.net/threads/-rms-v5-3-v5-4',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5948},
#     {'indicator': 'xiaomi-mi.com.ua/images/logo/updatesexplorer.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5949},
#     {'indicator': 'downloads.mortal-combat.by/target.php?uid=b266690a47e0ec1bb25b931d787408d68450b1f1&url=aHR0cDovL2NpdHlob3RlbC5raWV2LnVhL21lZGlhL2VkaXRvcnMvY29kZW1pcnJvci9BdHRhY2htZW50c19rcHNAcHMubWlsLmdvdi51YV8xNi4wMi4yMDE1LnJhcg==',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5950},
#     {'indicator': 'kif.ru/inc/catalog/install_flashplayer_aih',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5951},
#     {'indicator': 'http://ssu.kmu.gov.ua/sbu/doccatalog/document?id=138944',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5952},
#     {'indicator': 'cityhotel.ua/media/editors/codemirror/Attachments_kps@ps',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5953},
#     {'indicator': 'http://rms.admin-ru.ru/updater.php',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5954},
#     {'indicator': 'https://www.xaker.name/forvb/showthread.php?t=20588',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5955},
#     {'indicator': 'brokbridge.com/images/thumb/chrome-xvnc-v5517.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5956},
#     {'indicator': 'grom56.ddns.net:5500',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5957},
#     {'indicator': 'skidka.mobiboom.com.ua/ckeditor/lang/chromeupdates.exe',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5958},
#     {'indicator': 'downloads.file-attachments.ru/loads/install_flashplayer_aih',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5959},
#     {'indicator': 'grom90.ddns.net:5500',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5960},
#     {'indicator': 'cat.gotdns.ch:5500',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'URL',
#      'id': 5961},
#     {'indicator': 'downloads.file-attachments.ru',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5962},
#     {'indicator': 'downloads.email-attachments.ru',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5963},
#     {'indicator': 'rms.admin-ru.ru',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5964},
#     {'indicator': 'cat.gotdns.ch',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5965},
#     {'indicator': 'downloads.mortal-combat.by',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5966},
#     {'indicator': 'prestigeclub.frantov.com.ua',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5967},
#     {'indicator': 'skidka.mobiboom.com.ua',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5968},
#     {'indicator': 'grom56.ddns.net',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5969},
#     {'indicator': 'grom90.ddns.net',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 5970},
#     {'indicator': 'a67663ebc17f1b29fc14c8017f3185a5',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5971},
#     {'indicator': 'ec3f4213cc34ed77378df945058b79b0',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5972},
#     {'indicator': '3169e1f0b5b6590c394e5785ed49de8b',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5973},
#     {'indicator': 'ea8bb16f04985063be3c5e617c201681',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5974},
#     {'indicator': 'ca0bf99a875e39f8c2fb6aa17ae8e25b',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5975},
#     {'indicator': '75bcfc6b1e10d362a0170445b6b2bede',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5976},
#     {'indicator': '66ea2b2c415d6d79404725d1234a617f',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5977},
#     {'indicator': '40f7cc7f30c30c79ad7541a4cf0bf72b',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5978},
#     {'indicator': '7e1b6b1247a28d49260856818fb709bf',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5979},
#     {'indicator': 'a85115f97136d812317303306b8625d2',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5980},
#     {'indicator': '52f334f4f4fb7bbd60c96d208960032f',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5981},
#     {'indicator': '2abaf6748b3b3a8aad84f715ae3bd3c1',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5982},
#     {'indicator': '8f13977dfca4f6b0df6f8a9085cc300a',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5983},
#     {'indicator': '262777e5e1da79784c08acbb2002c169',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5984},
#     {'indicator': 'f9c4a48dd94a1e253db09824cd7eb907',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5985},
#     {'indicator': '7df924cbb8a41b7622cdf4f216c63026',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5986},
#     {'indicator': '85809a11bb0485842aadac46595b9e70',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5987},
#     {'indicator': '1b616b190291593d1b392f6fa9998422',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5988},
#     {'indicator': 'dada62ed88a4fb1239573b99fece59b2',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5989},
#     {'indicator': 'aa082aeebc5ab3ba00d3544959707634',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5990},
#     {'indicator': '34b9bbd2af740847267dd55e64957d44',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5991},
#     {'indicator': '64e8a194c73794f3b99ff0469946fba1',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5992},
#     {'indicator': '62de8fab8e2091cbd5a8897029b2c7ea',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5993},
#     {'indicator': '6edc4423414699340b5d245426472701',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5994},
#     {'indicator': '954764b31168f7c32c922321e3304403',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5995},
#     {'indicator': 'e45bae6295648e74689fc47bf4e730eb',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5996},
#     {'indicator': '2fcf797f2134bb860f784ca8f5bac4d7',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5997},
#     {'indicator': '86796d33483ca122612aa82a405f013b',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5998},
#     {'indicator': 'd43e1bbae9332de223d13840fcd21a76',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 5999},
#     {'indicator': '75ac3b194ce14bbe3b57a2b500e80734',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6000},
#     {'indicator': 'd29050bae02adc38e28fcf33622c06e9',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6001},
#     {'indicator': '8ff0fa4e0c195ca554b3ca7ec0694d3b',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6002},
#     {'indicator': '46cebeb27c7b8952a554b5cd7c49a9ae',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6003},
#     {'indicator': '4e3d45aa75822c52750ec5055697c964',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6004},
#     {'indicator': 'f5c0ff43501b31a8657750e863b409bc',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6005},
#     {'indicator': 'bdb7fc0c315df06efa17538fb4eb38cf',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6006},
#     {'indicator': '18813bf1bfa68dbb76752c5df32e10ae',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6007},
#     {'indicator': 'cc6f3382888b8f2ad39de288fba3e1ec',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6008},
#     {'indicator': '9fcff92538e35cd213a576d82e318c74',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6009},
#     {'indicator': 'b7e306e05b5cbd6ff64a0803c07cc32d',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6010},
#     {'indicator': '2dd8a3312635936041c686b5fc51c9ff',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6011},
#     {'indicator': 'd70215721a05a8289b6d80e7847eaf78',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6012},
#     {'indicator': 'ab567f299fd45509554eeeea578c967d',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6013},
#     {'indicator': '125970b313ee46ebb3dcd28b6e3268c6',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6014},
#     {'indicator': 'fb95de0cc4413a25e6d53fa25c3c5c0e',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6015},
#     {'indicator': 'a25ca9f94e43d35104ab4482100d630a',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6016},
#     {'indicator': 'e5052f47a02bdea469f8eab572d83ba8',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6017},
#     {'indicator': '76a45d72720a81ad580207b8293cdb17',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6018},
#     {'indicator': '456bad71881d1b456c1d0f96d94b5660',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6019},
#     {'indicator': 'c9de51cab6447bd557eaba11ea8f413f',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6020},
#     {'indicator': '8d99d6acccee2dbabb82b03b36554b06',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6021},
#     {'indicator': '30b727769de863360c5103ca7955e21b',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6022},
#     {'indicator': 'b59dca29c975258a83b24599b4000d6d',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6023},
#     {'indicator': 'b92e789aac1cc44f080d904371e1b9b5',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6024},
#     {'indicator': '0355db8425d97c343e5a7b4ecbf43852',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6025},
#     {'indicator': 'fd9af8cfa0d76e84cc783352a44e02e9',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6026},
#     {'indicator': '501a8319dfe24d7831533bd9b7f505e2',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6027},
#     {'indicator': '846af40e4e84e40a854482c3b20395c1',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6028},
#     {'indicator': '09be5e303b72716b3e3f074c7f63d2bd',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6029},
#     {'indicator': '08b36690af8f7a96e918eed11f42aeff',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6030},
#     {'indicator': '8dac6e9cf9b7f77250aa8cf0c62e1b2f',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6031},
#     {'indicator': 'c62438a6ab1d37df5afc712ce14995d9',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6032},
#     {'indicator': '286618df0aebbedcfd39a865cd4e6bd7',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6033},
#     {'indicator': '83c4d4fad2bbc3385e84ed4ae9767cdb',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6034},
#     {'indicator': '622ce511e8f8a68fac9feb06536cc8fb',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6035},
#     {'indicator': 'f125005055aed91873ce71010b67eb55',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6036},
#     {'indicator': '90f8f8ea411d767d833f9697dd0dabf4',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6037},
#     {'indicator': '11c4601d3968f689e87c71e6687a3853',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6038},
#     {'indicator': '4795fe6f5ce9557f6cbba6457b7931cc',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6039},
#     {'indicator': '9eebcee6f54b469a75d1360daf24fbb8',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6040},
#     {'indicator': 'e96dc19c669a999cf7a47907df5135e2',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6041},
#     {'indicator': '26aa5b2e3c6f68e9a92c891e99d2bc03',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6042},
#     {'indicator': '506aa7baf00535142870bf5536141921',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6043},
#     {'indicator': '33acb5b49688e609ef414ec762f180fb',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6044},
#     {'indicator': '09503ceeee5eff7fdbc75bb4e45012e7',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 6045},
#     {'indicator': 'b266690a47e0ec1bb25b931d787408d68450b1f1',
#      'description': '',
#      'created': '2015-04-29T16:11:08',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA1',
#      'id': 6046}],
#    'attack_ids': [],
#    'author': {'username': 'AlienVault',
#     'is_subscribed': True,
#     'avatar_url': 'https://otx20-web-media.s3.amazonaws.com/media/avatars/user_2/resized/80/avatar_dacfad0ca8.png',
#     'is_following': False,
#     'id': '2'},
#    'revision': 7,
#    'adversary': 'Gamaredon Group',
#    'id': '5541029cb45ff5029b148b7f',
#    'name': 'Operation Armageddon'},
#   {'industries': ['Government'],
#    'TLP': 'green',
#    'description': 'Servers of The Left in German Bundestag have been infected with malware, apparently by a state-sponsored group of Russian origin. This is the summary of an analysis by an IT security researcher, which we publish in full. The in-depth report provides an analysis of technology, impact, possible attribution – and a signature to detect the malware.',
#    'created': '2015-06-26T17:03:44.800000',
#    'tags': ['German Parliament',
#     'bundestagshack',
#     'apt28',
#     'sofacy',
#     'germany'],
#    'malware_families': [],
#    'modified': '2017-07-24T12:00:41.708000',
#    'author_name': 'AlienVault',
#    'public': 1,
#    'is_subscribing': None,
#    'references': ['https://netzpolitik.org/2015/digital-attack-on-german-parliament-investigative-report-on-the-hack-of-the-left-party-infrastructure-in-bundestag/'],
#    'targeted_countries': ['Germany'],
#    'indicators': [{'indicator': 'b12fa566e808c406e038af46012a8a28b76f58661872c0f76d12d9765aefa076',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA256',
#      'id': 12108},
#     {'indicator': '730a0e3daf0b54f065bdd2ca427fbe10e8d4e28646a5dc40cbcfb15e1702ed9a',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA256',
#      'id': 12109},
#     {'indicator': '5130f600cd9a9cdc82d4bad938b20cbd2f699aadb76e7f3f1a93602330d9997d',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA256',
#      'id': 12110},
#     {'indicator': '566ab945f61be016bfd9e83cc1b64f783b9b8deb891e6d504d3442bc8281b092',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA256',
#      'id': 12111},
#     {'indicator': '77e7fb6b56c3ece4ef4e93b6dc608be0',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 12112},
#     {'indicator': '5e70a5c47c6b59dae7faf0f2d62b28b3',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 12113},
#     {'indicator': 'f8292b67f20861a61d0716ebcfe56495',
#      'description': '',
#      'created': '2015-06-26T17:03:45',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-MD5',
#      'id': 12114},
#     {'indicator': '7d5c5ddfbb53bf83edc1c9ffadd98d5b93f0314b',
#      'description': '',
#      'created': '2017-07-22T10:16:22',
#      'title': '',
#      'content': 'rule apt_sofacy_xtunnel   \n   {   \n      meta:   \n        author = "Claudio Guarnieri"   \n      \n      strings:   \n         $xaps = ":\\\\PROJECT\\\\XAPS_"   \n      \n         $variant11 = "XAPS_OBJECTIVE.dll"   \n         $variant12 = "start"   \n      \n         $variant21 = "User-Agent: Mozilla/5.0 (Windows NT 6.3;"   \n         $variant22 = "is you live?"   \n      \n         $mix1 = "176.31.112.10"   \n         $mix2 = "error in select, errno %d"   \n         $mix3 = "no msg"   \n         $mix4 = "is you live?"   \n         $mix5 = "127.0.0.1"   \n         $mix6 = "err %d"   \n         $mix7 = "i`m wait"   \n         $mix8 = "hello"   \n         $mix9 = "OpenSSL 1.0.1e 11 Feb 2013"   \n         $mix10 = "Xtunnel.exe"   \n      \n      condition:   \n         ((uint16(0) == 0x5A4D) or (uint16(0) == 0xCFD0)) and   \n         (($xaps) or (all of ($variant1*)) or (all of ($variant2*))   \n   or (6 of ($mix*)))   \n   }',
#      'type': 'YARA',
#      'id': 28856644},
#     {'indicator': '2c36674e3e5b15a7b8b46400666bafb55264b7fb',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': 'rule Sofacy_Bundestag_Mal3    \n   {   \n      \n       meta:   \n           description = "Sofacy Group Malware Sample 3"   \n           author = "Florian Roth"   \n           reference = "http://dokumente.linksfraktion.de/inhalt/report-orig.pdf"   \n           date = "2015-06-19"   \n           hash = "5f6b2a0d1d966fc4f1ed292b46240767f4acb06c13512b0061b434ae2a692fa1"   \n           score = 70   \n         \n       strings:   \n           $s1 = "shell\\\\open\\\\command=\\"System Volume Information\\\\USBGuard.exe\\" install" fullword ascii    \n           $s2 = ".?AVAgentModuleRemoteKeyLogger@@" fullword ascii    \n           $s3 = "<font size=4 color=red>process isn\'t exist</font>" fullword ascii    \n           $s4 = "<font size=4 color=red>process is exist</font>" fullword ascii    \n           $s5 = ".winnt.check-fix.com" fullword ascii    \n           $s6 = ".update.adobeincorp.com" fullword ascii    \n           $s7 = ".microsoft.checkwinframe.com" fullword ascii   \n           $s8 = "adobeincorp.com" fullword wide    \n           $s9 = "# EXC: HttpSender - Cannot create Get Channel!" fullword ascii    \n           $x1 = "User-Agent: Mozilla/5.0 (Windows NT 6.2; WOW64; rv:20.0) Gecko/20100101 Firefox/" wide    \n           $x2 = "User-Agent: Mozilla/5.0 (Windows NT 6.; WOW64; rv:20.0) Gecko/20100101 Firefox/2" wide    \n           $x3 = "C:\\\\Windows\\\\System32\\\\cmd.exe" fullword wide    \n         \n       condition:   \n           uint16(0) == 0x5a4d and filesize < 300KB and ( 2 of ($s*) or ( 1 of ($s*) and all of ($x*) ))    \n   }',
#      'type': 'YARA',
#      'id': 30357067},
#     {'indicator': 'a5847b97c727258d54f1d9e7867d2731df8bf91c',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': 'rule Sofacy_Bundestag_Batch    \n   {   \n      \n       meta:   \n           description = "Sofacy Bundestags APT Batch Script"   \n           author = "Florian Roth"   \n           reference = "http://dokumente.linksfraktion.de/inhalt/report-orig.pdf"   \n           date = "2015-06-19"   \n           score = 70   \n       \n       strings:   \n           $s1 = "for %%G in (.pdf, .xls, .xlsx, .doc, .docx) do (" ascii    \n           $s2 = "cmd /c copy"   \n           $s3 = "forfiles"   \n        \n       condition:   \n           filesize < 10KB and all of them   \n   }',
#      'type': 'YARA',
#      'id': 30357068},
#     {'indicator': '43ae9a004ffaa736c2565b7063bb2f3e0304cf55',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': 'rule Sofacy_Bundestag_Mal2    \n   {   \n      \n       meta:   \n           description = "Sofacy Group Malware Sample 2"   \n           author = "Florian Roth"   \n           reference = "http://dokumente.linksfraktion.de/inhalt/report-orig.pdf"   \n           date = "2015-06-19"   \n           hash = "566ab945f61be016bfd9e83cc1b64f783b9b8deb891e6d504d3442bc8281b092"   \n           score = 70   \n         \n       strings:   \n           $x1 = "PROJECT\\\\XAPS_OBJECTIVE_DLL\\\\" ascii   \n           $x2 = "XAPS_OBJECTIVE.dll" fullword ascii   \n           $s1 = "i`m wait" fullword ascii    \n         \n       condition:   \n           uint16(0) == 0x5a4d and ( 1 of ($x*) ) and $s1   \n   }',
#      'type': 'YARA',
#      'id': 30357069},
#     {'indicator': '456da7fe6aad1eae949f42b6b187fa6616a119f5',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': 'rule Sofacy_Bundestag_Winexe   \n   {   \n      \n       meta:   \n           description = "Winexe tool used by Sofacy group in Bundestag APT"   \n           author = "Florian Roth"   \n           reference = "http://dokumente.linksfraktion.de/inhalt/report-orig.pdf"   \n           date = "2015-06-19"   \n           hash = "5130f600cd9a9cdc82d4bad938b20cbd2f699aadb76e7f3f1a93602330d9997d"   \n           score = 70   \n        \n       strings:   \n           $s1 = "\\\\\\\\.\\\\pipe\\\\ahexec" fullword ascii    \n           $s2 = "implevel" fullword ascii   \n        \n       condition:   \n           uint16(0) == 0x5a4d and filesize < 115KB and all of them   \n   }',
#      'type': 'YARA',
#      'id': 30357070},
#     {'indicator': '5f6b2a0d1d966fc4f1ed292b46240767f4acb06c13512b0061b434ae2a692fa1',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': '',
#      'type': 'FileHash-SHA256',
#      'id': 363301},
#     {'indicator': 'microsoft.checkwinframe.com',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 2179859},
#     {'indicator': 'update.adobeincorp.com',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 2179855},
#     {'indicator': 'winnt.check-fix.com',
#      'description': '',
#      'created': '2017-07-24T12:00:42',
#      'title': '',
#      'content': '',
#      'type': 'hostname',
#      'id': 2179833}],
#    'attack_ids': [],
#    'author': {'username': 'AlienVault',
#     'is_subscribed': True,
#     'avatar_url': 'https://otx20-web-media.s3.amazonaws.com/media/avatars/user_2/resized/80/avatar_dacfad0ca8.png',
#     'is_following': False,
#     'id': '2'},
#    'revision': 5,
#    'adversary': 'Sofacy',
#    'id': '558d85f0b45ff55ccb25e6f4',
#    'name': 'Digital Attack on German Parliament'}],
#  'count': 235,
#  'exact_match': ''}

# %%
json_normalize(pulses)[0:5]
# Out:
#    adversary attack_ids author_name                     created  \
# 0   WatchDog         []  AlienVault  2019-07-22T10:52:57.997000
# 1                    []  AlienVault  2019-07-24T15:38:37.671000
# 2  Dragonfly         []  AlienVault  2019-07-24T16:08:46.146000
# 3                    []  AlienVault  2019-07-24T15:21:12.326000
# 4        STC         []  AlienVault  2019-07-24T14:50:48.767000
#
#                                          description extract_source  \
# 0  Mining malware exploiting vulnerable Exim and ...             []
# 1  This pulse also includes indicators from a dif...             []
# 2  Since at least 2010, the IRON LIBERTY threat g...             []
# 3  Proofpoint researchers have identified a targe...             []
# 4  Lookout has discovered a highly targeted mobil...             []
#
#                          id  \
# 0  5d35958a9983df3a51f1a3b9
# 1  5d387b7db9eb38cf1cf02935
# 2  5d38828ec344a49024b2213f
# 3  5d3877688b1cacd5d94db112
# 4  5d3870489001dda95a515528
#
#                                           indicators  \
# 0  [{'indicator': 'CVE-2018-1000861', 'descriptio...
# 1  [{'indicator': 'www.d0m1c7devn.com', 'descript...
# 2  [{'indicator': 'tureg.info', 'description': ''...
# 3  [{'indicator': '304115cef6cc7b81f4409178cd0bce...
# 4  [{'indicator': 'zebraland.myftp.biz', 'descrip...
#
#                              industries malware_families  \
# 0                                    []               []
# 1                                    []               []
# 2                         [Energy, ICS]               []
# 3  [Government, Information Technology]               []
# 4                                    []               []
#
#                      modified  more_indicators  \
# 0  2019-07-25T08:14:59.614000            False
# 1  2019-07-24T16:14:54.232000            False
# 2  2019-07-24T16:09:55.808000            False
# 3  2019-07-24T15:21:12.326000            False
# 4  2019-07-24T15:04:06.918000            False
#
#                                                 name  public  \
# 0    WatchDog Mining Malware Exploiting Jira Servers       1
# 1                                   APT17 Identified       1
# 2  Dragonfly Targets ICS Systems Using Man on the...       1
# 3  Chinese APT “Operation LagTime IT” Targets Gov...       1
# 4                                            Monokle       1
#
#                                           references  revision  \
# 0  [https://twitter.com/polarply/status/115323298...         6
# 1  [https://intrusiontruth.wordpress.com/2019/07/...         2
# 2  [https://www.secureworks.com/research/resurgen...         2
# 3  [https://www.proofpoint.com/us/threat-insight/...         1
# 4  [https://www.lookout.com/documents/threat-repo...         1
#
#                                      tags targeted_countries    tlp
# 0                         [linux, monero]                 []  white
# 1                          [apt17, china]                 []  white
# 2  [energetic bear, iron liberty, russia]                 []  white
# 3                                 [China]                 []  white
# 4                   [mobile, stc, russia]                 []  white

# %%
json_normalize(pulses)[0:5]['indicators'][0]
# Out:
# [{'indicator': 'CVE-2018-1000861',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'CVE',
#   'id': 1606572483},
#  {'indicator': 'https://pastebin.com/raw/vvuYb1GC',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335319},
#  {'indicator': 'https://pastebin.com/raw/aGTSGJJp',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335320},
#  {'indicator': 'https://pastebin.com/raw/Zkz0d9Jz',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335321},
#  {'indicator': 'https://pastebin.com/raw/X6wvuv98',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335322},
#  {'indicator': 'https://pastebin.com/raw/KxWPFeEn',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335323},
#  {'indicator': 'https://pastebin.com/raw/KJcZ9HLL',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335324},
#  {'indicator': 'https://pastebin.com/raw/KGwfArMR',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335325},
#  {'indicator': 'https://pastebin.com/raw/J6NdVBHq',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335326},
#  {'indicator': 'https://pastebin.com/raw/EzqVke6X',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335327},
#  {'indicator': 'https://pastebin.com/raw/Dj3JTtnj',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335328},
#  {'indicator': 'https://pastebin.com/raw/B3R5Unwh',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335329},
#  {'indicator': 'https://pastebin.com/raw/AgdgACUD',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335330},
#  {'indicator': 'https://pastebin.com/raw/05p0fTYd',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335331},
#  {'indicator': 'https://pastebin.com/2unJiD3b',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335332},
#  {'indicator': 'z5r6anrjbcasuikp.onion.to',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'hostname',
#   'id': 2121335333},
#  {'indicator': 'http://45.55.211.79/%27',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335334},
#  {'indicator': 'https://z5r6anrjbcasuikp.onion.to/',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335335},
#  {'indicator': 'https://pixeldra.in/api/download/nZ2s4L',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'URL',
#   'id': 2121335336},
#  {'indicator': '65cfcad6dc3d31695b8f3ffa08e5d389',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2121335337},
#  {'indicator': '95721de55ad89005484b4c21f768d94e',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2121335338},
#  {'indicator': '157495f6ba8c36c38984d1f902cf3ac0',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2121335339},
#  {'indicator': '314097a1d41697352c961026aa1ed87c',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2121335340},
#  {'indicator': '1dbd97c70a89e64cbfb65c78ac39938e',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2121335341},
#  {'indicator': 'CVE-2019-1003000',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'CVE',
#   'id': 2121335342},
#  {'indicator': 'jeff4r-partner@tutanota.com',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:52:59',
#   'content': '',
#   'type': 'email',
#   'id': 2121335343},
#  {'indicator': '26ebeac4492616baf977903bb8deb7803bd5a22d8a005f02398c188b0375dfa4',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T10:53:26',
#   'content': '',
#   'type': 'FileHash-SHA256',
#   'id': 2121335345},
#  {'indicator': '82ee3a6c2e3d53ccf85108a6c644c0b9',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T11:05:25',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2121340069},
#  {'indicator': '1db603370e30234ca2cbd5cd84f5683f76f21513',
#   'description': '',
#   'title': '',
#   'created': '2019-07-22T11:05:25',
#   'content': '',
#   'type': 'FileHash-SHA1',
#   'id': 2121340070},
#  {'indicator': 'https://pastebin.com/raw/mvSEGmR6',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098080},
#  {'indicator': 'https://pastebin.com/raw/dXD2Bs0H',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098081},
#  {'indicator': "https://pastebin.com/raw/X6wvuv98'",
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098082},
#  {'indicator': 'https://pastebin.com/raw/W1YkrqHk',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098083},
#  {'indicator': 'https://pastebin.com/raw/SB0TYBvG',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098084},
#  {'indicator': 'https://pastebin.com/raw/LUN80Hj8',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098085},
#  {'indicator': "https://pastebin.com/raw/KxWPFeEn'",
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098086},
#  {'indicator': 'https://pastebin.com/raw/4HvzGfGm',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098087},
#  {'indicator': 'https://pastebin.com/raw/3LU3Rj7p',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098088},
#  {'indicator': 'https://pastebin.com/raw/3FDDiNwW',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098089},
#  {'indicator': 'https://pastebin.com/raw/2unJiD3b',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098090},
#  {'indicator': "https://pastebin.com/raw/05p0fTYd'",
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098091},
#  {'indicator': 'aziplcr72qjhzvin.onion.to',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'hostname',
#   'id': 2122098092},
#  {'indicator': 'jeff4r-partner@protonmail.com',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'email',
#   'id': 2122098093},
#  {'indicator': 'https://aziplcr72qjhzvin.onion.to/old.txt',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098094},
#  {'indicator': 'https://pixeldrain.com/api/file/ZuVWceWG',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'URL',
#   'id': 2122098095},
#  {'indicator': 'jeff4r190@tutanota.com',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T09:27:42',
#   'content': '',
#   'type': 'email',
#   'id': 2122098096},
#  {'indicator': 'https://pastebin.com/raw/p3mGdbpq',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T10:01:24',
#   'content': '',
#   'type': 'URL',
#   'id': 2122118111},
#  {'indicator': 'https://pastebin.com/raw/UeynzXEr',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T10:01:24',
#   'content': '',
#   'type': 'URL',
#   'id': 2122118112},
#  {'indicator': 'https://pastebin.com/raw/MMCFQMH9',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T10:01:24',
#   'content': '',
#   'type': 'URL',
#   'id': 2122118113},
#  {'indicator': 'https://z5r6anrjbcasuikp.onion.to',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T10:01:24',
#   'content': '',
#   'type': 'URL',
#   'id': 2122118114},
#  {'indicator': 'b17829d758e8689143456240ebd79b420f963722707246f5dc9b085a411f7b5e',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T17:12:57',
#   'content': '',
#   'type': 'FileHash-SHA256',
#   'id': 2122476806},
#  {'indicator': '5c78f0147ee12f7f77c02cfc31f0cc55b69baf0ca3fbd954239e17cd3f81cc3f',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T17:12:57',
#   'content': '',
#   'type': 'FileHash-SHA256',
#   'id': 2122476807},
#  {'indicator': '5dddfe5a9a3f14846457a63d6e28db5b',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T17:12:57',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2122476808},
#  {'indicator': 'f839fc8e7f22be30d73286fd665c8c3c',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T17:12:57',
#   'content': '',
#   'type': 'FileHash-MD5',
#   'id': 2122476809},
#  {'indicator': '2d887dd10e55b94cf36f6a48bd11502addac63f6',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T17:12:57',
#   'content': '',
#   'type': 'FileHash-SHA1',
#   'id': 2122476810},
#  {'indicator': '6467be07bfe5342270e3c536c45ab95645dc39d0',
#   'description': '',
#   'title': '',
#   'created': '2019-07-23T17:12:57',
#   'content': '',
#   'type': 'FileHash-SHA1',
#   'id': 2122476811},
#  {'indicator': 'cdf11a1fa7e551fe6be1f170ba9dedee80401396adf7e39ccde5df635c1117a9',
#   'description': '',
#   'title': '',
#   'created': '2019-07-25T08:14:52',
#   'content': '',
#   'type': 'FileHash-SHA256',
#   'id': 2124738231},
#  {'indicator': 'https://7dc5fb4e.ngrok.io',
#   'description': '',
#   'title': '',
#   'created': '2019-07-25T08:14:52',
#   'content': '',
#   'type': 'URL',
#   'id': 2124738232},
#  {'indicator': 'https://9d842cb6.ngrok.io',
#   'description': '',
#   'title': '',
#   'created': '2019-07-25T08:14:52',
#   'content': '',
#   'type': 'URL',
#   'id': 2124738233},
#  {'indicator': '7dc5fb4e.ngrok.io',
#   'description': '',
#   'title': '',
#   'created': '2019-07-25T08:14:52',
#   'content': '',
#   'type': 'hostname',
#   'id': 2124738234},
#  {'indicator': '9d842cb6.ngrok.io',
#   'description': '',
#   'title': '',
#   'created': '2019-07-25T08:14:52',
#   'content': '',
#   'type': 'hostname',
#   'id': 2124738235}]

# %% [markdown]
# - author_name: The username of the OTX User that created the pulse
# - created: Date when the pulse was created in the system
# - description: Describes the pulse in terms of the type of threat it poses, and any other facts that may link it to other threat indicators.
# - id: Unique identifier of the pulse
# - indicators: Collection of Indicators Of Compromise
# - modified: Date when the pulse was last modified
# - name: Name of the pulse
# - references: List of references to papers, websites or blogs related to the threat described in the pulse
# - revision: Revision number that increments each time pulse contents change
# - tags: List of tags that provide information about pulse content, for example, Phshing, malware, C&C, and apt.

# %% [markdown]
# Let's explore the indicators object:

# %%
json_normalize(pulses[1]["indicators"])
# Out:
#    content              created description          id  \
# 0           2019-07-24T15:38:39                  479354
# 1           2019-07-24T15:38:39                  699150
# 2           2019-07-24T15:38:39                  955276
# 3           2019-07-24T15:38:39                 1766725
# 4           2019-07-24T16:14:14                 2607222
# 5           2019-07-24T16:14:14                 2611569
# 6           2019-07-24T15:38:39                36480907
# 7           2019-07-24T15:38:39                36480908
# 8           2019-07-24T15:38:39                36480913
# 9           2019-07-24T15:38:39                77070661
# 10          2019-07-24T15:38:39                77070664
# 11          2019-07-24T15:38:39                77070676
# 12          2019-07-24T15:38:39                77070680
# 13          2019-07-24T15:38:39                77070684
# 14          2019-07-24T15:38:39                77070691
# 15          2019-07-24T15:38:39                77070695
# 16          2019-07-24T15:38:39                77070696
# 17          2019-07-24T15:38:39              1593635352
# 18          2019-07-24T15:38:39              1674885923
# 19          2019-07-24T15:38:39              1674885924
# 20          2019-07-24T15:38:39              2123812795
# 21          2019-07-24T15:38:39              2123812796
# 22          2019-07-24T15:38:39              2123812797
# 23          2019-07-24T15:38:39              2123812798
# 24          2019-07-24T15:38:39              2123812799
# 25          2019-07-24T15:38:39              2123812800
# 26          2019-07-24T15:38:39              2123812801
# 27          2019-07-24T15:38:39              2123812802
# 28          2019-07-24T15:38:39              2123812803
# 29          2019-07-24T15:38:39              2123812804
# ..     ...                  ...         ...         ...
# 44          2019-07-24T15:38:39              2123812819
# 45          2019-07-24T15:38:39              2123812820
# 46          2019-07-24T15:38:39              2123812821
# 47          2019-07-24T15:38:39              2123812822
# 48          2019-07-24T15:38:39              2123812823
# 49          2019-07-24T15:38:39              2123812824
# 50          2019-07-24T15:38:39              2123812825
# 51          2019-07-24T15:38:39              2123812826
# 52          2019-07-24T15:38:39              2123812827
# 53          2019-07-24T15:38:39              2123812828
# 54          2019-07-24T15:38:39              2123812829
# 55          2019-07-24T15:38:39              2123812830
# 56          2019-07-24T15:38:39              2123812831
# 57          2019-07-24T15:38:39              2123812832
# 58          2019-07-24T15:38:39              2123812833
# 59          2019-07-24T15:38:39              2123812834
# 60          2019-07-24T15:38:39              2123812835
# 61          2019-07-24T15:38:39              2123812836
# 62          2019-07-24T15:38:39              2123812837
# 63          2019-07-24T15:38:39              2123812838
# 64          2019-07-24T15:38:39              2123812839
# 65          2019-07-24T15:38:39              2123812840
# 66          2019-07-24T15:38:39              2123812841
# 67          2019-07-24T15:38:39              2123812842
# 68          2019-07-24T15:38:39              2123812843
# 69          2019-07-24T15:38:39              2123812844
# 70          2019-07-24T16:14:14              2123841473
# 71          2019-07-24T16:14:54              2123843214
# 72          2019-07-24T16:14:54              2123843215
# 73          2019-07-24T16:14:54              2123843216
#
#                                             indicator title             type
# 0                                  www.d0m1c7devn.com               hostname
# 1   0b52c5338af355699530a47683420e48c7344e779d3e81...        FileHash-SHA256
# 2                                 accounts-googlc.com                 domain
# 3   ce7127c38e30e92a021ed2bd09287713c6a923db9ffdb4...        FileHash-SHA256
# 4                                   matrix.bcvziy.com               hostname
# 5                                          bcvziy.com                 domain
# 6   7c54e1a5dbabf54d0cd43028218d38e5f83158f3f52355...        FileHash-SHA256
# 7   fc0fad39b461eb1cfc6be57932993fcea94fca65056427...        FileHash-SHA256
# 8                  www.thyssenkrupp-marinesystems.org               hostname
# 9                      thyssenkrupp-marinesystems.org                 domain
# 10                                      usdagroup.com                 domain
# 11  5860ddc428ffa900258207e9c385f843a3472f2fbf252d...        FileHash-SHA256
# 12  ced7ca9625543d3d3d09f70223cc19f0d99e2179285445...        FileHash-SHA256
# 13                                godie.usdagroup.com               hostname
# 14                           rsc-to.teledynegroup.com               hostname
# 15                             usda.teledynegroup.com               hostname
# 16                                 whoi.usdagroup.com               hostname
# 17  57976133193b732bb5602345d6aa7ff83555a365f41521...        FileHash-SHA256
# 18                                  backup.wscsvc.net               hostname
# 19                                  access.wscsvc.net               hostname
# 20                            www.accounts-googlc.com               hostname
# 21                                         wscsvc.net                 domain
# 22                                        secbkav.com                 domain
# 23                                  teledynegroup.com                 domain
# 24                                          yqdac.com                 domain
# 25  02966d799a0c22d81e5878aa9b2389da4af892d0481409...        FileHash-SHA256
# 26                                          pir0i.com                 domain
# 27                                        yahxi123.cn                 domain
# 28                                   thyssemkrupp.com                 domain
# 29                                          dpc0p.com                 domain
# ..                                                ...   ...              ...
# 44                        http://exchange.wscsvc.net/                    URL
# 45                        http://accounts-googlc.com/                    URL
# 46  http://backup.wscsvc.net/fb13c3cf930f5714f9081...                    URL
# 47  http://backup.wscsvc.net/4ad40fc46bd1dd7cf97cf...                    URL
# 48  http://www.wscsvc.net:8080/logon.aspx?Id=s07PD...                    URL
# 49  http://exchange.wscsvc.net/d1a326be4a422e92308...                    URL
# 50                          http://access.wscsvc.net/                    URL
# 51  http://exchange.wscsvc.net/0777ae914c11045d001...                    URL
# 52                                    www.secbkav.com               hostname
# 53                                  www.usdagroup.com               hostname
# 54                                exchange.wscsvc.net               hostname
# 55                                     ns1.wscsvc.net               hostname
# 56                                     www.wscsvc.net               hostname
# 57                              ftp.teledynegroup.com               hostname
# 58                              www.teledynegroup.com               hostname
# 59                shop.thyssenkrupp-marinesystems.org               hostname
# 60                                     1si2.yqdac.com               hostname
# 61                             back.teledynegroup.com               hostname
# 62                   d1a326be4a422e92308bbcf8ea154f6d           FileHash-MD5
# 63                   4ad40fc46bd1dd7cf97cf0568c86956f           FileHash-MD5
# 64                   d901a5737d7a0c37aa42798cb523150f           FileHash-MD5
# 65                   fb13c3cf930f5714f9081a49844209e7           FileHash-MD5
# 66                   007cf8d976ee0862487c78ec071ce2e7           FileHash-MD5
# 67                   0777ae914c11045d00159744ccdc8109           FileHash-MD5
# 68           14d4ce4666ee1a0dc0ed341c9007934d3aba401f          FileHash-SHA1
# 69                                    emm@ph4nt0m.org                  email
# 70                                      ibackdoor.net                 domain
# 71                                     www.missll.com               hostname
# 72                     http://www.missll.com/file.exe                    URL
# 73                                         missll.com                 domain
#
# [74 rows x 7 columns]

# %% [markdown]
# - _id: Unique identifier of the IOC
# - created: Date IOC was added to the pulse
# - description: Describe the Indicator Of Compromise
# - indicator: The IOC
# - indicator_type: Type of indicator
#
# The following Indicator Types are supported (also defined in IndicatorTypes.py):

# %%
indicator_types = [
			{
			    "name": "IPv4", 
			    "description": "An IPv4 address indicating the online location of a server or other computer."
			}, 
			{
			    "name": "IPv6", 
			    "description": "An IPv6 address indicating the online location of a server or other computer."
			}, 
			{
			    "name": "domain", 
			    "description": "A domain name for a website or server. Domains encompass a series of hostnames."
			}, 
			{
			    "name": "hostname", 
			    "description": "The hostname for a server located within a domain."
			}, 
			{
			     
			    "name": "email", 
			    "description": "An email associated with suspicious activity."
			}, 
			{
			    "name": "URL", 
			    "description": " Uniform Resource Location (URL) summarizing the online location of a file or resource."
			}, 
			{
			     
			    "name": "URI", 
			    "description": "Uniform Resource Indicator (URI) describing the explicit path to a file hosted online."
			}, 
			{
			    "name": "FileHash-MD5", 
			    "description": "A MD5-format hash that summarizes the architecture and content of a file."
			}, 
			{
			    "name": "FileHash-SHA1", 
			    "description": "A SHA-format hash that summarizes the architecture and content of a file."
			}, 
			{
			    "name": "FileHash-SHA256", 
			    "description": "A SHA-256-format hash that summarizes the architecture and content of a file."
			}, 
			{
			     
			    "name": "FileHash-PEHASH", 
			    "description": "A PEPHASH-format hash that summarizes the architecture and content of a file."
			}, 
			{
			     
			    "name": "FileHash-IMPHASH", 
			    "description": "An IMPHASH-format hash that summarizes the architecture and content of a file."
			}, 
			{
			    "name": "CIDR", 
			    "description": "Classless Inter-Domain Routing (CIDR) address, which describes both a server's IP address and the network architecture (routing path) surrounding that server."
			}, 
			{
			     
			    "name": "FilePath", 
			    "description": "A unique location in a file system."
			}, 
			{
			     
			    "name": "Mutex", 
			    "description": "The name of a mutex resource describing the execution architecture of a file."
			}, 
			{
			    "name": "CVE", 
			    "description": "Common Vulnerability and Exposure (CVE) entry describing a software vulnerability that can be exploited to engage in malicious activity."
			}]

# %%
json_normalize(indicator_types)
# Out:
#                                           description              name
# 0   An IPv4 address indicating the online location...              IPv4
# 1   An IPv6 address indicating the online location...              IPv6
# 2   A domain name for a website or server. Domains...            domain
# 3   The hostname for a server located within a dom...          hostname
# 4       An email associated with suspicious activity.             email
# 5    Uniform Resource Location (URL) summarizing t...               URL
# 6   Uniform Resource Indicator (URI) describing th...               URI
# 7   A MD5-format hash that summarizes the architec...      FileHash-MD5
# 8   A SHA-format hash that summarizes the architec...     FileHash-SHA1
# 9   A SHA-256-format hash that summarizes the arch...   FileHash-SHA256
# 10  A PEPHASH-format hash that summarizes the arch...   FileHash-PEHASH
# 11  An IMPHASH-format hash that summarizes the arc...  FileHash-IMPHASH
# 12  Classless Inter-Domain Routing (CIDR) address,...              CIDR
# 13                A unique location in a file system.          FilePath
# 14  The name of a mutex resource describing the ex...             Mutex
# 15  Common Vulnerability and Exposure (CVE) entry ...               CVE

# %%
mtime = (datetime.now() - timedelta(days=1)).isoformat()

# %%
mtime
# Out:
# '2019-07-24T15:33:25.060991'

# %% [markdown]
# ## Events

# %% [markdown]
# Besides receiving the pulse information, there is another function that can retrieve different events that are ocurring in the OTX system and affect your account.

# %%
events = otx.getevents_since(mtime)

# %%
json_normalize(events)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# - id: object id of this event.  Unique reference identifier
# - action : "[subscribe | unsubscribe | delete]", Currently supports subscribe / unsubscribe events for users and pulses and delete events for pulses
# - object_type : "[pulse | user]", // Currently supports events for pulse and user objects
# - object_id : "[pulse id | author id]", // Unique id can be used to lookup pulses and users (e.g. to remove them from  system, they would remove all pulses by author_id or an individual pulse by pulse "id".
# "created" : <timestamp of event>

# %% [markdown]
# When developing an application, you must decide how you want to handle different types of events. For instance, if one OTX user unsubscribes from another user, do you want to delete the IOCs the second user contributed from your application? How do you plan to reconcile the data on the server versus the data in your application?
# The same question comes up when users delete a pulse.

# %% [markdown]
# ## Using Search and get Pulse by ID

# %% [markdown]
# The OTX API allows you to search for pulses and users by keyword.  This allows you to obtain pulses that you're not (yet) subscribed to.

# %%
pulses = otx.search_pulses("Russian")

# %%
json_normalize(pulses["results"])
# Out:
#      TLP        adversary attack_ids  \
# 0  green           Sofacy         []
# 1  green           Sofacy         []
# 2  green             None         []
# 3  green  Gamaredon Group         []
# 4  green           Sofacy         []
#
#                                    author.avatar_url author.id  \
# 0  https://otx20-web-media.s3.amazonaws.com/media...         2
# 1  https://otx20-web-media.s3.amazonaws.com/media...         2
# 2  https://otx.alienvault.com/assets/images/defau...        49
# 3  https://otx20-web-media.s3.amazonaws.com/media...         2
# 4  https://otx20-web-media.s3.amazonaws.com/media...         2
#
#    author.is_following  author.is_subscribed author.username author_name  \
# 0                False                  True      AlienVault  AlienVault
# 1                False                  True      AlienVault  AlienVault
# 2                False                 False          tomdaq      tomdaq
# 3                False                  True      AlienVault  AlienVault
# 4                False                  True      AlienVault  AlienVault
#
#                       created  ...    industries is_subscribing  \
# 0  2015-04-10T18:15:11.492000  ...            []           None
# 1  2015-04-20T02:56:30.505000  ...            []           None
# 2  2015-04-20T22:54:45.662000  ...            []           None
# 3  2015-04-29T16:11:08.251000  ...            []           None
# 4  2015-06-26T17:03:44.800000  ...  [Government]           None
#
#   malware_families                    modified  \
# 0               []  2019-01-25T15:20:10.359000
# 1               []  2017-08-24T10:45:07.905000
# 2               []  2015-04-20T22:54:45.662000
# 3               []  2017-03-12T01:33:45.089000
# 4               []  2017-07-24T12:00:41.708000
#
#                                        name public  \
# 0  Potential TV5 Monde intrusion indicators      1
# 1                     Operation RussianDoll      1
# 2                         Operation Buhtrap      1
# 3                      Operation Armageddon      1
# 4       Digital Attack on German Parliament      1
#
#                                           references revision  \
# 0  [https://www.bluecoat.com/security-blog/2015-0...       11
# 1                                                 []        3
# 2                                                 []        1
# 3                                                 []        7
# 4  [https://netzpolitik.org/2015/digital-attack-o...        5
#
#                                                 tags targeted_countries
# 0                                                 []                 []
# 1  [flash, apt28, windows, apt, shellcode, zeroda...                 []
# 2  [windows, microsoft word, backdoor, kaspersky,...                 []
# 3     [Lookingglass, russia, ukraine, spearphishing]                 []
# 4  [German Parliament, bundestagshack, apt28, sof...          [Germany]
#
# [5 rows x 23 columns]

# %% [markdown]
# Let's say we're interested in viewing the full details (including indicators) from one of our search results.  For example maybe we're interested in the Enigma Ransomware:

# %%
pulse_id = pulses["results"][0]["id"]

# %%
pulse_id = '2118732129'

# %%
pulse_details = otx.get_pulse_details(pulse_id)

# %%
json_normalize(pulse_details)
# Out:
#      TLP adversary attack_ids  \
# 0  green      None         []
#
#                                    author.avatar_url author.id  \
# 0  https://otx20-web-media.s3.amazonaws.com/media...         2
#
#    author.is_following  author.is_subscribed author.username author_name  \
# 0                False                  True      AlienVault  AlienVault
#
#                       created  ... industries is_subscribing malware_families  \
# 0  2014-11-19T19:00:59.709000  ...         []           None               []
#
#                      modified                  name public  \
# 0  2017-10-31T23:40:15.891000  PoS Scammers Toolbox      1
#
#                                           references revision  tags  \
# 0  [https://blog.trendmicro.com/trendlabs-securit...        1    []
#
#   targeted_countries
# 0                 []
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Indicator details

# %% [markdown]
# Let's investigate an indicator included in the Enigma Ransomware pulse.

# %%
indicator = pulse_details["indicators"][4]["indicator"]

# %%
indicator_details = otx.get_indicator_details_full(IndicatorTypes.IPv4, indicator)

# %% [markdown]
# Indicator details are divided into sections for convenience:

# %%
indicator_details.keys()

# %%
json_normalize(indicator_details["url_list"])

# %%
json_normalize(indicator_details["passive_dns"].get('passive_dns'))

# %% [markdown]
# Indicator details are not available for all supported indicator types.  IndicatorTypes.supported_api_types contains a list of the indicator types you can use with get_indicator_details_by_section and get_indicator_details_full.

# %% [markdown]
# ## Create pulse

# %% [markdown]
# You can create new pulses using the create_pulse function.  A name string is required.  Public boolean is also required but will be set True if not provided:

# %%
indicators = [{"indicator": "82.194.84.121", "description":"", "type": "IPv4"}, {"indicator": "82.194.84.122", "description":"", "type": "IPv4"}]

# %%
new_pulse = otx.create_pulse(name="IPy Notebook Test", indicators=indicators, public=False)

# %%
json_normalize(new_pulse)

# %% [markdown]
# The following fields can be passed into create_pulse:
# - name(string, required) pulse name
# - public(boolean, required) long form description of threat
# - description(string) long form description of threat
# - tlp(string, white/green/amber/red) Traffic Light Protocol level for threat sharing
# - tags(list of strings) short keywords to associate with your pulse
# - references(list of strings, preferably URLs) external references for this threat
# - indicators(list of objects) IOCs to include in pulse
